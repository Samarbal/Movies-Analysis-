# %% [markdown]
# 1. استيراد المكتبات وقراءة البيانات

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# two tpyes of pandas : series - one diemnsion , dataframe two dimensions

# %%
df = pd.read_csv('movies_complete.csv')

# %% [markdown]
# 2. استكشاف أولي للبيانات (Data Exploration)

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   10/30/1995
# 1              Roll the dice and unleash the excitement!   12/15/1995
# 2      Still Yelling. Still Fighting. Still Ready for...   12/22/1995
# 3      Friends are the people who let you be yourself...   12/22/1995
# 4      Just When His World Is Back To Normal... He's ...    2/10/1995
# ...

# %%
# the first 5 rows of the dataframe
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   10/30/1995
# 1          Roll the dice and unleash the excitement!   12/15/1995
# 2  Still Yelling. Still Fighting. Still Ready for...   12/22/1995
# 3  Friends are the people who let you be yourself...   12/22/1995
# 4  Just When His World Is Back To Normal... He's ...    2/10/1995
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
# the last 5 rows of the dataframe
df.tail(10)
# Out:
#            id                      title  \
# 44681   84419           House of Horrors
# 44682  390959  Shadow of the Blair Witch
# 44683  289923        The Burkittsville 7
# 44684  222848            Caged Heat 3000
# 44685   30840                 Robin Hood
# 44686  439050                     Subdue
# 44687  111109        Century of Birthing
# 44688   67758                   Betrayal
# 44689  227506           Satan Triumphant
# 44690  461257                   Queerama
#
#                                                  tagline release_date  \
# 44681                                Meet...The CREEPER!    3/29/1946
# 44682                                                NaN   10/22/2000
# 44683  Do you know what happened 50 years before "The...    10/3/2000
# 44684                                                NaN     1/1/1995
# 44685                                                NaN    5/13/1991
# 44686         Rising and falling between a man and woman          NaN
# ...

# %%
# sample 
df.sample(8)
# Out:
#            id                   title  \
# 22820  151043       A Man Called Adam
# 4162      301               Rio Bravo
# 9632    12228      Inside Deep Throat
# 12146    1874          Goodbye Bafana
# 16890   43817         White Lightnin'
# 19469   59897  Where the Boys Are '84
# 40400  150657           Merry In-Laws
# 43896  436343        On Body and Soul
#
#                                                  tagline release_date  \
# 22820                                                NaN    3/16/1966
# 4162   They fought back to back...No quarter given......    3/17/1959
# 9632   It was filmed in 6 days for 25 thousand dollar...    2/11/2005
# 12146                                                NaN    2/11/2007
# 16890                                                NaN    1/19/2009
# 19469  When girls want a vacation filled with fun, sa...     4/6/1984
# 40400                                                NaN    12/8/2012
# ...

# %%
# sample with percentage 
sample_df = df.sample(frac=0.01)
sample_df
# Out:
#            id                          title  \
# 16154   20526                   TRON: Legacy
# 34319  358881                 Made in France
# 26437  113823          Three Guys Named Mike
# 29184   28969           The Velveteen Rabbit
# 39286   25356            The Break-up Artist
# ...       ...                            ...
# 38277  354818  Colin Quinn: Unconstitutional
# 33419  335392             Religion In Crisis
# 13170   14306                    Marley & Me
# 21015   91063            It's a Bikini World
# 2735    28377                     Hell Night
#
#                                       tagline release_date  \
# 16154                   The Game Has Changed.   12/10/2010
# 34319                                     NaN   10/27/2015
# 26437                                     NaN     3/1/1951
# 29184          All You Need to Do is Believe.     1/1/2009
# 39286              Breaking up is easy to do!     8/9/2009
# ...                                       ...          ...
# ...

# %%
# shuffled dataset , fraction = 1 
shuffled_df = df.sample(frac=1)
shuffled_df
# Out:
#            id                                       title  \
# 30147   14406                    Mariage chez les Bodin's
# 32849   16854                                  Snapphanar
# 23224  198185                          Million Dollar Arm
# 41332   43641  Superman/Shazam!: The Return of Black Adam
# 36045  211105                             Krishna Cottage
# ...       ...                                         ...
# 16934   42521                           Idiots and Angels
# 17916   74536                           The Son of No One
# 40289   55602                                Buried Alive
# 38392  339148               Already Tomorrow in Hong Kong
# 17642   76684                                       Masti
#
#                                                  tagline release_date  \
# 30147                                                NaN    9/24/2008
# 32849                                                NaN   11/22/2006
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  int64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
# statistical info about numeric data columns 
df.describe()
# Out:
#                   id  budget_musd  revenue_musd    vote_count  vote_average  \
# count   44691.000000  8854.000000   7385.000000  44691.000000  42077.000000
# mean   107186.242845    21.669886     68.968649    111.653778      6.003341
# std    111806.362236    34.359837    146.608966    495.322313      1.281060
# min         2.000000     0.000001      0.000001      0.000000      0.000000
# 25%     26033.500000     2.000000      2.405420      3.000000      5.300000
# 50%     59110.000000     8.200000     16.872671     10.000000      6.100000
# 75%    154251.000000    25.000000     67.642693     35.000000      6.800000
# max    469172.000000   380.000000   2787.965087  14075.000000     10.000000
#
#          popularity       runtime     cast_size     crew_size
# count  44691.000000  43179.000000  44691.000000  44691.000000
# mean       2.957460     97.566850     12.479090     10.313643
# std        6.040008     34.653409     12.124663     15.892154
# ...

# %%
df.describe().T
# Out:
#                 count           mean            std       min           25%  \
# id            44691.0  107186.242845  111806.362236  2.000000  26033.500000
# budget_musd    8854.0      21.669886      34.359837  0.000001      2.000000
# revenue_musd   7385.0      68.968649     146.608966  0.000001      2.405420
# vote_count    44691.0     111.653778     495.322313  0.000000      3.000000
# vote_average  42077.0       6.003341       1.281060  0.000000      5.300000
# popularity    44691.0       2.957460       6.040008  0.000000      0.402038
# runtime       43179.0      97.566850      34.653409  1.000000     86.000000
# cast_size     44691.0      12.479090      12.124663  0.000000      6.000000
# crew_size     44691.0      10.313643      15.892154  0.000000      2.000000
#
#                        50%            75%            max
# id            59110.000000  154251.000000  469172.000000
# budget_musd       8.200000      25.000000     380.000000
# ...

# %%
df.dtypes
# Out:
# id                         int64
# title                     object
# tagline                   object
# release_date              object
# genres                    object
# belongs_to_collection     object
# original_language         object
# budget_musd              float64
# revenue_musd             float64
# production_companies      object
# production_countries      object
# vote_count                 int64
# vote_average             float64
# popularity               float64
# runtime                  float64
# overview                  object
# spoken_languages          object
# poster_path               object
# cast                      object
# cast_size                  int64
# crew_size                  int64
# director                  object
# dtype: object

# %% [markdown]
# 3. عمليات Slicing

# %%
# slicing 
df_50 = df[:50]
df_random = df[100: 200]

# %% [markdown]
# 4. تقسيم البيانات (Training / Testing)

# %%
cut_off = int(len(df)*0.7)
train_df = df[:cut_off]
test_df = df [cut_off: ]

# %%
# what is used for ??
df[10:200:3]
# Out:
#          id                                             title  \
# 10     9087                            The American President
# 13    10858                                             Nixon
# 16     4584                             Sense and Sensibility
# 19    11517                                       Money Train
# 22     9691                                         Assassins
# ..      ...                                               ...
# 187   32646                                              Safe
# 190   10149                                             Smoke
# 193  139408                       The Stars Fell on Henrietta
# 196   79593                                The Tie That Binds
# 199    9090  To Wong Foo, Thanks for Everything! Julie Newmar
#
#                                                tagline release_date  \
# 10   Why can't the most powerful man in the world h...   11/17/1995
# 13   Triumphant in Victory, Bitter in Defeat. He Ch...   12/22/1995
# ...

# %% [markdown]
# 5. تحليل بصري أولي (Exploring distributions)

# %%
# for numeric columns , helps in detecting the outliers 
df.hist(figsize = (20, 10), bins=100)
# vote count has some outliers
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'budget_musd'}>,
#         <Axes: title={'center': 'revenue_musd'}>],
#        [<Axes: title={'center': 'vote_count'}>,
#         <Axes: title={'center': 'vote_average'}>,
#         <Axes: title={'center': 'popularity'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'cast_size'}>,
#         <Axes: title={'center': 'crew_size'}>]], dtype=object)

# %%
#how to reach for a specific column in the dataset 
print (df.title)
df[['title', 'budget_musd', 'genres']].values # without the index , as an array
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object
# array([['Toy Story', 30.0, 'Animation|Comedy|Family'],
#        ['Jumanji', 65.0, 'Adventure|Fantasy|Family'],
#        ['Grumpier Old Men', nan, 'Romance|Comedy'],
#        ...,
#        ['Betrayal', nan, 'Action|Drama|Thriller'],
#        ['Satan Triumphant', nan, nan],
#        ['Queerama', nan, nan]], dtype=object)

# %% [markdown]
# 6. الوصول للأعمدة

# %%
df2 = df[['title', 'budget_musd', 'genres']]
df2.head()
# Out:
#                          title  budget_musd                    genres
# 0                    Toy Story         30.0   Animation|Comedy|Family
# 1                      Jumanji         65.0  Adventure|Fantasy|Family
# 2             Grumpier Old Men          NaN            Romance|Comedy
# 3            Waiting to Exhale         16.0      Comedy|Drama|Romance
# 4  Father of the Bride Part II          NaN                    Comedy

# %% [markdown]
# 7. حذف الأعمدة

# %%
# drop columns , inplace for changing the dataframe 
df2.drop(columns = ['budget_musd'],  inplace= True)
# Out:
# C:\Users\pc home\AppData\Local\Temp\ipykernel_16344\1040343219.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns = ['budget_musd'],  inplace= True)

# %%
df2.columns
# Out:
# Index(['title', 'genres'], dtype='object')

# %% [markdown]
# 8. إحصائيات عامة

# %%
print ('The mean budget = ' , df["budget_musd"].mean())
print ('The max budget = ' , df['budget_musd'].max())
print ('The min budget = ' , df['budget_musd'].min())
# Out:
# The mean budget =  21.66988615111814
# The max budget =  380.0
# The min budget =  1e-06

# %% [markdown]
# 9. Value Counts

# %%
# counts how many repeated values in a column
df['director'].value_counts()[:20]
# Out:
# director
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Woody Allen           49
# Georges Méliès        49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# George Cukor          38
# Fritz Lang            38
# John Huston           38
# Robert Altman         37
# Mervyn LeRoy          37
# Name: count, dtype: int64

# %%
df["genres"].value_counts()[:10]
# Out:
# genres
# Drama                   4935
# Comedy                  3581
# Documentary             2670
# Drama|Romance           1291
# Comedy|Drama            1125
# Horror                   962
# Comedy|Romance           921
# Comedy|Drama|Romance     591
# Drama|Comedy             528
# Horror|Thriller          527
# Name: count, dtype: int64

# %%
print (len(df["original_language"].value_counts()))
print (df["original_language"].unique())
df["original_language"].value_counts()[:5]
# Out:
# 89
# ['en' 'fr' 'zh' 'it' 'fa' 'nl' 'de' 'cn' 'ar' 'es' 'ru' 'sv' 'ja' 'ko'
#  'sr' 'bn' 'he' 'pt' 'wo' 'ro' 'hu' 'cy' 'vi' 'cs' 'da' 'no' 'nb' 'pl'
#  'el' 'sh' 'xx' 'mk' 'bo' 'ca' 'fi' 'th' 'sk' 'bs' 'hi' 'tr' 'is' 'ps'
#  'ab' 'eo' 'ka' 'mn' 'bm' 'zu' 'uk' 'af' 'la' 'et' 'ku' 'fy' 'lv' 'ta'
#  'sl' 'tl' 'ur' 'rw' 'id' 'bg' 'mr' 'lt' 'kk' 'ms' 'sq' nan 'qu' 'te' 'am'
#  'jv' 'tg' 'ml' 'hr' 'lo' 'ay' 'kn' 'eu' 'ne' 'pa' 'ky' 'gl' 'uz' 'sm'
#  'mt' 'hy' 'iu' 'lb' 'si']
# original_language
# en    31755
# fr     2400
# it     1471
# ja     1339
# de     1064
# Name: count, dtype: int64

# %%
df["production_companies"].value_counts().head(5)
# Out:
# production_companies
# Metro-Goldwyn-Mayer (MGM)                 741
# Warner Bros.                              540
# Paramount Pictures                        501
# Twentieth Century Fox Film Corporation    438
# Universal Pictures                        317
# Name: count, dtype: int64

# %%
df["production_countries"].value_counts().head(5)
# Out:
# production_countries
# United States of America    17723
# United Kingdom               2228
# France                       1636
# Japan                        1348
# Italy                        1017
# Name: count, dtype: int64

# %% [markdown]
# 10. ترتيب البيانات

# %%
df.sort_values(by = ["title", "genres"], ascending=False)
# Out:
#            id                                              title  \
# 40829  252874                                           ファンタスティポ
# 38452  109380                    …And the Fifth Horseman Is Fear
# 8812    14670                                    ’Round Midnight
# 37891  120249  ‘Rameau’s Nephew’ by Diderot (Thanx to Dennis ...
# 22109  388182                                     هیچ کجا هیچ کس
# ...       ...                                                ...
# 27734  143747                                $1,000 on the Black
# 23248  267752                                       #chicagoGirl
# 35656  301325                                            #Horror
# 30587   41371                                #1 Cheerleader Camp
# 18588   55245                              !Women Art Revolution
#
#                                         tagline release_date  \
# 40829                                       NaN    2/10/2005
# ...

# %%
df.sort_values(by= ['budget_musd' , 'title'] , ascending= False )
# Out:
#            id                                        title  \
# 16986    1865  Pirates of the Caribbean: On Stranger Tides
# 11743     285     Pirates of the Caribbean: At World's End
# 26268   99861                      Avengers: Age of Ultron
# 10985    1452                             Superman Returns
# 44095  335988                Transformers: The Last Knight
# ...       ...                                          ...
# 34497  158079                           $100,000 for Ringo
# 27734  143747                          $1,000 on the Black
# 23248  267752                                 #chicagoGirl
# 30587   41371                          #1 Cheerleader Camp
# 18588   55245                        !Women Art Revolution
#
#                                               tagline release_date  \
# 16986                     Live Forever Or Die Trying.    5/14/2011
# 11743  At the end of the world, the adventure begins.    5/19/2007
# ...

# %% [markdown]
# 11. القيم المفقودة

# %%
df.isna() 
df.isnull().sum()
# Out:
# id                           0
# title                        0
# tagline                  24407
# release_date                34
# genres                    2105
# belongs_to_collection    40228
# original_language           10
# budget_musd              35837
# revenue_musd             37306
# production_companies     11335
# production_countries      5856
# vote_count                   0
# vote_average              2614
# popularity                   0
# runtime                   1512
# overview                   951
# spoken_languages          3597
# poster_path                224
# cast                      2189
# cast_size                    0
# crew_size                    0
# director                   731
# dtype: int64

# %%
df.budget_musd.isna().sum()
# Out:
# np.int64(35837)

# %%
df['budget_musd'] =   df.budget_musd.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            44691 non-null  float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  int64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df['revenue_musd'] = df['revenue_musd'].fillna( df['revenue_musd'].mean())

# %%
df['revenue_musd']
# Out:
# 0        373.554033
# 1        262.797249
# 2         68.968649
# 3         81.452156
# 4         76.578911
#             ...
# 44686     68.968649
# 44687     68.968649
# 44688     68.968649
# 44689     68.968649
# 44690     68.968649
# Name: revenue_musd, Length: 44691, dtype: float64

# %% [markdown]
# 12. تحليلات إضافية

# %%
# details of top 10 movies in term of budgets 
df.sort_values(by = ['budget_musd'], ascending= False)[:10]
# Out:
#            id                                        title  \
# 16986    1865  Pirates of the Caribbean: On Stranger Tides
# 11743     285     Pirates of the Caribbean: At World's End
# 26268   99861                      Avengers: Age of Ultron
# 10985    1452                             Superman Returns
# 16006   38757                                      Tangled
# 44095  335988                Transformers: The Last Knight
# 18517   49529                                  John Carter
# 11696     559                                 Spider-Man 3
# 20959   57201                              The Lone Ranger
# 18090   49026                        The Dark Knight Rises
#
#                                               tagline release_date  \
# 16986                     Live Forever Or Die Trying.    5/14/2011
# 11743  At the end of the world, the adventure begins.    5/19/2007
# 26268                             A New Age Has Come.    4/22/2015
# ...

# %%
#avrage number of crew size of all movies , 
df['crew_size'].mean()
# Out:
# np.float64(10.313642567854826)

# %%
#top directore in term of production movies

# %%
# list of unique production conutries 
df.production_countries.unique()
# Out:
# array(['United States of America', 'Germany|United States of America',
#        'United Kingdom|United States of America', ...,
#        'Poland|Czech Republic|Slovakia', 'Cuba|Germany|Spain',
#        'Egypt|Italy|United States of America'], dtype=object)

# %%
#new dataframe arranged by title , bugeget , revenue 
new_df = df[['title','budget_musd', 'revenue_musd'  ]]
new_df
# Out:
#                              title  budget_musd  revenue_musd
# 0                        Toy Story         30.0    373.554033
# 1                          Jumanji         65.0    262.797249
# 2                 Grumpier Old Men          0.0     68.968649
# 3                Waiting to Exhale         16.0     81.452156
# 4      Father of the Bride Part II          0.0     76.578911
# ...                            ...          ...           ...
# 44686                       Subdue          0.0     68.968649
# 44687          Century of Birthing          0.0     68.968649
# 44688                     Betrayal          0.0     68.968649
# 44689             Satan Triumphant          0.0     68.968649
# 44690                     Queerama          0.0     68.968649
#
# [44691 rows x 3 columns]
